# %% [markdown]
# Naive Bayes Algorithm
# -------------------------
#     It is a supervised Machine Learning algorithm
#
#     Used for classification
#
#     Based on probability
#
#     Classifieers worked based on Bayes Theorem
#
#     Conditional probability

# %% [markdown]
# Probability
# ------
#     Chances of occurences
#
#     Probability of head in a coin flip -- 1/2
#
#     Probability of tail in a coin flip -- 1/2
#
# Conditional Probability
# -----------
#     The chances of occurence of an event based on another event that has already occured
#
#     P( A|B ) == (P( A Intersection)) / P(B)
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# ernklm_bigdata
#
# ernklm_python
#
# ernklm_testing
#
# thr_bigdata
#
# thr_testing
#
# thr_python
#
# ernklm_bigdata
#
# calicut_python
#
# calicut_bigdata
#
# calicut_testing
#
# calicut_python
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# P(Ernakulam) = 4/11
#
# P(thrissur) = 3/11
#
# P(Calicur) = 4/11
#
#
# P(bigdata/ernakulam) = 2/4
#
# P(python/thrissur) = 1/3
#
#
#
#
# Equation
# --------
# -------------------------------------------------------
# P(A/B) = ( P(B/A) * P(A) ) / P(B)
#
#
# Technical terms
