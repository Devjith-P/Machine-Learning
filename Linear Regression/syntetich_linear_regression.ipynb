# %%
import pandas as pd

# %%
df = pd.read_csv("/home/devjith/Luminar/Machine Learning/files/syntetic_linear_regression.csv")

# %%
df
# Out:
#             x          y
# 0    3.745401  20.997409
# 1    9.507143  33.598279
# 2    7.319939  34.520777
# 3    5.986585  31.005976
# 4    1.560186  15.259605
# ..        ...        ...
# 995  0.915821   3.605260
# 996  9.173136  36.047130
# 997  1.368186  11.603468
# 998  9.502374  38.111796
# 999  4.460058  19.148097
#
# [1000 rows x 2 columns]

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3,random_state=42)

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("X vs Y")
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,y_pred,color = 'r')

# %%
print(model.coef_)
# Out:
# [3.41179266]

# %%
print(model.intercept_)
# Out:
# 8.03895445395602

# %%
df2 = pd.DataFrame({
    "Actual value":y_test,
    "Predicted Value": y_pred,
    "Difference ": y_test-y_pred
})

# %%
df2
# Out:
#      Actual value  Predicted Value  Difference
# 521     25.291392        21.034161     4.257231
# 737     38.735039        35.899634     2.835405
# 740     29.298961        23.824629     5.474332
# 660     22.777792        20.188236     2.589555
# 411     33.582041        40.453099    -6.871057
# ..            ...              ...          ...
# 468     15.994784        15.667581     0.327203
# 935     16.078090        17.329516    -1.251426
# 428     12.268999        20.011447    -7.742448
# 7       39.612065        37.591089     2.020977
# 155     12.961663        16.297378    -3.335715
#
# [300 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,root_mean_squared_error,r2_score

mae = mean_absolute_error(y_test,y_pred)
mape = mean_absolute_percentage_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = root_mean_squared_error(y_test,y_pred)
r2score = r2_score(y_test,y_pred)

# %%
print(f" Mean Absolute error {mae},\n Mean absolute percentage error {mape},\n Mean squared error {mse},\n Root mean squared error {rmse},\n r2 score {r2score}")
# Out:
#  Mean Absolute error 3.7383939108644517,
#  Mean absolute percentage error 0.26464032264007165,
#  Mean squared error 22.591227941642156,
#  Root mean squared error 4.753023031886355,
#  r2 score 0.8144646586719524
