# %% [markdown]
# Simple Linear Regression
# ====

# %% [markdown]
# AREA        PRICE
#
# 2600        5500000
#
# 3000        6100000
#
# 3200        6250000
#
# 3600        6800000
#
# 4000        7100000
#
# 3500            ?

# %%
area = [2600,3000,3200,3600,4000]
price = [550000,6100000,6250000,6800000,7100000]

# %%
import matplotlib.pyplot as plt

plt.scatter(area,price)
